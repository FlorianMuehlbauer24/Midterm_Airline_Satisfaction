# %% [markdown]
# ### READING THE DATASET

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/FlorianMuehlbauer24/Midterm_Airline_Satisfaction/19bec508b94c864d278ffcab56db7e6f695a2feb/df_airline.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# 2                                  2  ...                       5
# 3                                  5  ...                       2
# 4                                  3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (103904, 25)

# %%
df['Type of Travel'].unique()
# Out:
# array(['Personal Travel', 'Business travel'], dtype=object)

# %%
df['Class'].unique()
# Out:
# array(['Eco Plus', 'Business', 'Eco'], dtype=object)

# %%
df.nunique()
# Out:
# Unnamed: 0                           103904
# id                                   103904
# Gender                                    2
# Customer Type                             2
# Age                                      75
# Type of Travel                            2
# Class                                     3
# Flight Distance                        3802
# Inflight wifi service                     6
# Departure/Arrival time convenient         6
# Ease of Online booking                    6
# Gate location                             6
# Food and drink                            6
# Online boarding                           6
# Seat comfort                              6
# Inflight entertainment                    6
# On-board service                          6
# Leg room service                          6
# Baggage handling                          5
# Checkin service                           6
# Inflight service                          6
# Cleanliness                               6
# Departure Delay in Minutes              446
# Arrival Delay in Minutes                455
# satisfaction                              2
# dtype: int64

# %% [markdown]
# ### DATA WRANGLING

# %%
# standarlizing all column names
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')
df.head()
# Out:
#    unnamed:_0      id  gender      customer_type  age   type_of_travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       class  flight_distance  inflight_wifi_service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    departure/arrival_time_convenient  ...  inflight_entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# 2                                  2  ...                       5
# 3                                  5  ...                       2
# 4                                  3  ...                       3
#
#    on-board_service  leg_room_service  baggage_handling  checkin_service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    inflight_service  cleanliness  departure_delay_in_minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    arrival_delay_in_minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 25 columns]

# %%
# Filter only for business
selected_values = ['Business']
condition = df['class'].isin(selected_values)

df = df[condition].copy()

df.head()
# Out:
#    unnamed:_0      id  gender      customer_type  age   type_of_travel  \
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
# 7           7   96462  Female     Loyal Customer   52  Business travel
#
#       class  flight_distance  inflight_wifi_service  \
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
# 7  Business             2035                      4
#
#    departure/arrival_time_convenient  ...  inflight_entertainment  \
# 1                                  2  ...                       1
# 2                                  2  ...                       5
# 3                                  5  ...                       2
# 4                                  3  ...                       3
# 7                                  3  ...                       5
#
#    on-board_service  leg_room_service  baggage_handling  checkin_service  \
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
# 7                 5                 5                 5                4
#
#    inflight_service  cleanliness  departure_delay_in_minutes  \
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
# 7                 5            4                           4
#
#    arrival_delay_in_minutes             satisfaction
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
# 7                       0.0                satisfied
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (49665, 25)

# %% [markdown]
# ### ENCODING

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (49533, 25)

# %%
df = df.drop_duplicates()

# %%
# Reset index
df = df.reset_index()

# %%
df.columns
# Out:
# Index(['index', 'unnamed:_0', 'id', 'gender', 'customer_type', 'age',
#        'type_of_travel', 'class', 'flight_distance', 'inflight_wifi_service',
#        'departure/arrival_time_convenient', 'ease_of_online_booking',
#        'gate_location', 'food_and_drink', 'online_boarding', 'seat_comfort',
#        'inflight_entertainment', 'on-board_service', 'leg_room_service',
#        'baggage_handling', 'checkin_service', 'inflight_service',
#        'cleanliness', 'departure_delay_in_minutes', 'arrival_delay_in_minutes',
#        'satisfaction'],
#       dtype='object')

# %%
# Export CSV to use in Tableau
df_for_export = df[['age', 'type_of_travel','online_boarding', 'checkin_service', 'on-board_service', 'baggage_handling', 'inflight_service', 'leg_room_service', 'cleanliness', 'seat_comfort', 'inflight_wifi_service', 'arrival_delay_in_minutes', 'departure_delay_in_minutes', 'satisfaction']]
df_for_export.to_csv('exported_data.csv', index=False)
from google.colab import files
files.download('exported_data.csv')

# %%
# Create Categorical and Numercial DF
categorical_df = df.select_dtypes(include='object')
numerical_df = df.select_dtypes(include ='number')

# %%
# Check categorical df
categorical_df.head()
# Out:
#    gender      customer_type   type_of_travel     class  \
# 0    Male  disloyal Customer  Business travel  Business
# 1  Female     Loyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3    Male     Loyal Customer  Business travel  Business
# 4  Female     Loyal Customer  Business travel  Business
#
#               satisfaction
# 0  neutral or dissatisfied
# 1                satisfied
# 2  neutral or dissatisfied
# 3                satisfied
# 4                satisfied

# %%
# Check numberical df
numerical_df.head()
# Out:
#    index  unnamed:_0      id  age  flight_distance  inflight_wifi_service  \
# 0      1           1    5047   25              235                      3
# 1      2           2  110028   26             1142                      2
# 2      3           3   24026   25              562                      2
# 3      4           4  119299   61              214                      3
# 4      7           7   96462   52             2035                      4
#
#    departure/arrival_time_convenient  ease_of_online_booking  gate_location  \
# 0                                  2                       3              3
# 1                                  2                       2              2
# 2                                  5                       5              5
# 3                                  3                       3              3
# 4                                  3                       4              4
#
#    food_and_drink  ...  seat_comfort  inflight_entertainment  \
# 0               1  ...             1                       1
# 1               5  ...             5                       5
# 2               2  ...             2                       2
# 3               4  ...             5                       3
# 4               5  ...             5                       5
#
#    on-board_service  leg_room_service  baggage_handling  checkin_service  \
# 0                 1                 5                 3                1
# 1                 4                 3                 4                4
# 2                 2                 5                 3                1
# 3                 3                 4                 4                3
# 4                 5                 5                 5                4
#
#    inflight_service  cleanliness  departure_delay_in_minutes  \
# 0                 4            1                           1
# 1                 4            5                           0
# 2                 4            2                          11
# 3                 3            3                           0
# 4                 5            4                           4
#
#    arrival_delay_in_minutes
# 0                       6.0
# 1                       0.0
# 2                       9.0
# 3                       0.0
# 4                       0.0
#
# [5 rows x 21 columns]

# %%
# Translate categorical_df into numerical values
categorical_df = pd.get_dummies(categorical_df[['gender','customer_type','type_of_travel','class','satisfaction']], dtype=int)

# %%
# Check modified categorical_df with numerical values
print(categorical_df.head)
# Out:
# <bound method NDFrame.head of        gender_Female  gender_Male  customer_type_Loyal Customer  \
# 0                  0            1                             0
# 1                  1            0                             1
# 2                  1            0                             1
# 3                  0            1                             1
# 4                  1            0                             1
# ...              ...          ...                           ...
# 49528              0            1                             1
# 49529              1            0                             1
# 49530              0            1                             1
# 49531              0            1                             0
# 49532              0            1                             1
#
#        customer_type_disloyal Customer  type_of_travel_Business travel  \
# 0                                    1                               1
# 1                                    0                               1
# 2                                    0                               1
# 3                                    0                               1
# 4                                    0                               1
# ...                                ...                             ...
# 49528                                0                               1
# 49529                                0                               1
# 49530                                0                               1
# 49531                                1                               1
# 49532                                0                               1
#
#        type_of_travel_Personal Travel  class_Business  \
# 0                                   0               1
# 1                                   0               1
# 2                                   0               1
# 3                                   0               1
# 4                                   0               1
# ...                               ...             ...
# 49528                               0               1
# 49529                               0               1
# 49530                               0               1
# 49531                               0               1
# 49532                               0               1
#
#        satisfaction_neutral or dissatisfied  satisfaction_satisfied
# 0                                         1                       0
# 1                                         0                       1
# 2                                         1                       0
# 3                                         0                       1
# 4                                         0                       1
# ...                                     ...                     ...
# 49528                                     0                       1
# 49529                                     0                       1
# 49530                                     0                       1
# 49531                                     1                       0
# 49532                                     1                       0
#
# [49533 rows x 9 columns]>

# %%
df_combined = pd.concat([categorical_df, numerical_df], axis=1)

# %%
df_combined = df_combined.drop(['index', 'unnamed:_0', 'id', 'satisfaction_neutral or dissatisfied'], axis=1)

# %%
df_combined.head()
# Out:
#    gender_Female  gender_Male  customer_type_Loyal Customer  \
# 0              0            1                             0
# 1              1            0                             1
# 2              1            0                             1
# 3              0            1                             1
# 4              1            0                             1
#
#    customer_type_disloyal Customer  type_of_travel_Business travel  \
# 0                                1                               1
# 1                                0                               1
# 2                                0                               1
# 3                                0                               1
# 4                                0                               1
#
#    type_of_travel_Personal Travel  class_Business  satisfaction_satisfied  \
# 0                               0               1                       0
# 1                               0               1                       1
# 2                               0               1                       0
# 3                               0               1                       1
# 4                               0               1                       1
#
#    age  flight_distance  ...  seat_comfort  inflight_entertainment  \
# 0   25              235  ...             1                       1
# 1   26             1142  ...             5                       5
# 2   25              562  ...             2                       2
# 3   61              214  ...             5                       3
# 4   52             2035  ...             5                       5
#
#    on-board_service  leg_room_service  baggage_handling  checkin_service  \
# 0                 1                 5                 3                1
# 1                 4                 3                 4                4
# 2                 2                 5                 3                1
# 3                 3                 4                 4                3
# 4                 5                 5                 5                4
#
#    inflight_service  cleanliness  departure_delay_in_minutes  \
# 0                 4            1                           1
# 1                 4            5                           0
# 2                 4            2                          11
# 3                 3            3                           0
# 4                 5            4                           4
#
#    arrival_delay_in_minutes
# 0                       6.0
# 1                       0.0
# 2                       9.0
# 3                       0.0
# 4                       0.0
#
# [5 rows x 26 columns]

# %%
df_combined.shape
# Out:
# (49533, 26)

# %%
df_combined['satisfaction_satisfied'].unique()
# Out:
# array([0, 1])

# %%
# Analyzing the proporction of unique values of the target variable
df_combined['satisfaction_satisfied'].value_counts()
# Out:
# 1    34390
# 0    15143
# Name: satisfaction_satisfied, dtype: int64

# %%
# !pip install -U imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.12.0-py3-none-any.whl (257 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.7/257.7 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.2.0)
# Installing collected packages: imbalanced-learn
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.10.1
#     Uninstalling imbalanced-learn-0.10.1:
#       Successfully uninstalled imbalanced-learn-0.10.1
# Successfully installed imbalanced-learn-0.12.0

# %%
from imblearn.combine import SMOTEENN
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ### SPLIT

# %%
X = df_combined.drop(columns = ["satisfaction_satisfied"]) # everything but y variable
y = df_combined[["satisfaction_satisfied"]]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,random_state = 100)

# %% [markdown]
# ### RESTORING BALANCE IN TARGET V

# %%
# Apply SMOTEENN to apply undersampling on the training set
undersampler = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = undersampler.fit_resample(X_train, y_train)

# %% [markdown]
# ### ANALYZING SKEWNESS IN DATASET

# %%
import matplotlib.pyplot as plt

selected_columns = ['gender_Female', 'gender_Male', 'customer_type_Loyal Customer',
       'customer_type_disloyal Customer', 'type_of_travel_Business travel',
       'type_of_travel_Personal Travel', 'class_Business', 'age',
       'flight_distance', 'inflight_wifi_service',
       'departure/arrival_time_convenient', 'ease_of_online_booking',
       'gate_location', 'food_and_drink', 'online_boarding', 'seat_comfort',
       'inflight_entertainment', 'on-board_service', 'leg_room_service',
       'baggage_handling', 'checkin_service', 'inflight_service',
       'cleanliness', 'departure_delay_in_minutes',
       'arrival_delay_in_minutes']

X_train_resampled[selected_columns].hist(bins=10, figsize=(12, 10), sharex=False)
plt.suptitle('Histograms of Selected Numerical Features', y=1.02, fontsize=16)
plt.show()

# %%
X_train_resampled.head()
# Out:
#        gender_Female  gender_Male  customer_type_Loyal Customer  \
# 18779              0            1                             0
# 43797              0            1                             1
# 34195              0            1                             0
# 44384              0            1                             1
# 19179              1            0                             1
#
#        customer_type_disloyal Customer  type_of_travel_Business travel  \
# 18779                                1                               1
# 43797                                0                               1
# 34195                                1                               1
# 44384                                0                               1
# 19179                                0                               1
#
#        type_of_travel_Personal Travel  class_Business  age  flight_distance  \
# 18779                               0               1   34              522
# 43797                               0               1   54             3346
# 34195                               0               1   52              946
# 44384                               0               1   46             2747
# 19179                               0               1   32             1615
#
#        inflight_wifi_service  ...  seat_comfort  inflight_entertainment  \
# 18779                      2  ...             3                       1
# 43797                      2  ...             4                       2
# 34195                      2  ...             2                       2
# 44384                      4  ...             4                       4
# 19179                      4  ...             4                       4
#
#        on-board_service  leg_room_service  baggage_handling  checkin_service  \
# 18779                 4                 3                 3                3
# 43797                 2                 2                 2                4
# 34195                 4                 5                 4                3
# 44384                 4                 4                 4                4
# 19179                 4                 5                 4                2
#
#        inflight_service  cleanliness  departure_delay_in_minutes  \
# 18779                 3            3                         141
# 43797                 2            2                           0
# 34195                 4            2                           5
# 44384                 4            4                           0
# 19179                 3            4                           0
#
#        arrival_delay_in_minutes
# 18779                     125.0
# 43797                       0.0
# 34195                       0.0
# 44384                       0.0
# 19179                       0.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### DATA SCALING AND TRANSFORMATION

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PowerTransformer
import numpy as np

# %%
# Iniciated the PowerTransformer my my case # "pt is the scaler
pt = PowerTransformer()

# Fit the transformer to my X_train data
pt.fit(X_train_resampled)
# Out:
# PowerTransformer()

# %%
# Transform X_train using the fitted transformer and convert it back to a DataFrame
X_train_scaled = pd.DataFrame(pt.transform(X_train_resampled), columns=X_train_resampled.columns)

# Transform X_test using the fitted transformer and convert it back to a DataFrame
X_test_scaled = pd.DataFrame(pt.transform(X_test), columns=X_test.columns)

# %%
X_train_scaled.head()
# Out:
#    gender_Female  gender_Male  customer_type_Loyal Customer  \
# 0      -1.010254     1.010254                     -2.064441
# 1      -1.010254     1.010254                      0.484393
# 2      -1.010254     1.010254                     -2.064441
# 3      -1.010254     1.010254                      0.484393
# 4       0.989850    -0.989850                      0.484393
#
#    customer_type_disloyal Customer  type_of_travel_Business travel  \
# 0                         2.064441                        0.263737
# 1                        -0.484393                        0.263737
# 2                         2.064441                        0.263737
# 3                        -0.484393                        0.263737
# 4                        -0.484393                        0.263737
#
#    type_of_travel_Personal Travel  class_Business       age  flight_distance  \
# 0                       -0.263737   -9.313226e-10 -0.509155        -0.932982
# 1                       -0.263737   -9.313226e-10  0.990560         1.333418
# 2                       -0.263737   -9.313226e-10  0.843050        -0.365100
# 3                       -0.263737   -9.313226e-10  0.397542         1.014683
# 4                       -0.263737   -9.313226e-10 -0.662688         0.261033
#
#    inflight_wifi_service  ...  seat_comfort  inflight_entertainment  \
# 0              -0.453596  ...     -0.568114               -1.696470
# 1              -0.453596  ...      0.289681               -1.070325
# 2              -0.453596  ...     -1.267863               -1.070325
# 3               1.005977  ...      0.289681                0.447240
# 4               1.005977  ...      0.289681                0.447240
#
#    on-board_service  leg_room_service  baggage_handling  checkin_service  \
# 0          0.377434         -0.399014         -0.707166        -0.364348
# 1         -1.184281         -1.125497         -1.391694         0.491980
# 2          0.377434          1.309267          0.182864        -0.364348
# 3          0.377434          0.415988          0.182864         0.491980
# 4          0.377434          1.309267          0.182864        -1.123066
#
#    inflight_service  cleanliness  departure_delay_in_minutes  \
# 0         -0.716938    -0.257492                    1.645000
# 1         -1.401235    -1.003697                   -0.843039
# 2          0.175831    -1.003697                    0.735072
# 3          0.175831     0.546173                   -0.843039
# 4         -0.716938     0.546173                   -0.843039
#
#    arrival_delay_in_minutes
# 0                  1.622593
# 1                 -0.853063
# 2                 -0.853063
# 3                 -0.853063
# 4                 -0.853063
#
# [5 rows x 25 columns]

# %% [markdown]
# ### TRANING THE LOGISTIC REGRESSION MODEL

# %%
from sklearn.linear_model import LogisticRegression

# %%
y_train_resampled_flat = y_train_resampled.values.ravel() # y_train needed to be converted with ravel()

model = LogisticRegression()
model.fit(X_train_scaled, y_train_resampled_flat)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test_scaled)

# %%
unique_values = np.unique(y_pred)
unique_values
# Out:
# array([0, 1])

# %%
random_row = X_test.sample()
random_row
# Out:
#        gender_Female  gender_Male  customer_type_Loyal Customer  \
# 22725              1            0                             1
#
#        customer_type_disloyal Customer  type_of_travel_Business travel  \
# 22725                                0                               1
#
#        type_of_travel_Personal Travel  class_Business  age  flight_distance  \
# 22725                               0               1   45              834
#
#        inflight_wifi_service  ...  seat_comfort  inflight_entertainment  \
# 22725                      2  ...             4                       2
#
#        on-board_service  leg_room_service  baggage_handling  checkin_service  \
# 22725                 2                 2                 2                2
#
#        inflight_service  cleanliness  departure_delay_in_minutes  \
# 22725                 2            3                           0
#
#        arrival_delay_in_minutes
# 22725                       0.0
#
# [1 rows x 25 columns]

# %%
predicted_class = model.predict(random_row)
predicted_class
# Out:
# array([0])

# %%
model.intercept_
# Out:
# array([0.20325498])

# %%
model.coef_
# Out:
# array([[ 5.32958677e-03, -5.32958677e-03,  5.74647049e-01,
#         -5.74647049e-01,  5.76206866e-01, -5.76206866e-01,
#         -1.87218411e-10, -1.25316245e-01, -4.48570499e-02,
#         -2.76315426e-01, -1.18955359e-01, -2.09023403e-02,
#          1.80060856e-01, -2.85038785e-02,  1.35693719e+00,
#          2.89625259e-01, -1.94398118e-01,  5.33526825e-01,
#          5.12501109e-01,  5.13818914e-01,  5.78281173e-01,
#          5.12734881e-01,  4.73828348e-01,  2.86942467e-02,
#         -2.35162945e-01]])

# %% [markdown]
# ### MODEL EVALUATION

# %% [markdown]
# #### CONFUSION MATRIX

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[3439  333]
#  [1190 7422]]

# %%
# Plot the heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", linewidths=.5, annot_kws={"size": 16})
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# #### ACCURACY SCORE

# %%
from sklearn.metrics import accuracy_score

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8770187338501292

# %% [markdown]
# #### CLASSICIFATION REPORT

# %%
# Generate classification report
classification_report_result = classification_report(y_test, y_pred)
print("Classification Report:\n", classification_report_result)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.91      0.82      3772
#            1       0.96      0.86      0.91      8612
#
#     accuracy                           0.88     12384
#    macro avg       0.85      0.89      0.86     12384
# weighted avg       0.89      0.88      0.88     12384

# %% [markdown]
# ### FEATURE IMPORTANCE FROM MASCHINE LEARNING

# %%
feature_names = X_train_scaled.columns
coefficients = pd.DataFrame({'Feature': feature_names, 'Coefficient': model.coef_[0]})

# %%
# Sort coefficients by magnitude
coefficients = coefficients.reindex(coefficients['Coefficient'].abs().sort_values(ascending=False).index)

# Print sorted coefficients
print("Feature Importance - Logistic Regression:")
print(coefficients)

# Visualize feature importance
plt.figure(figsize=(10, 6))
plt.barh(coefficients['Feature'], coefficients['Coefficient'])
plt.xlabel('Coefficient Magnitude')
plt.title('Feature Importance - Logistic Regression')
plt.show()
# Out:
# Feature Importance - Logistic Regression:
#                               Feature   Coefficient
# 14                    online_boarding  1.356937e+00
# 20                    checkin_service  5.782812e-01
# 4      type_of_travel_Business travel  5.762069e-01
# 5      type_of_travel_Personal Travel -5.762069e-01
# 2        customer_type_Loyal Customer  5.746470e-01
# 3     customer_type_disloyal Customer -5.746470e-01
# 17                   on-board_service  5.335268e-01
# 19                   baggage_handling  5.138189e-01
# 21                   inflight_service  5.127349e-01
# 18                   leg_room_service  5.125011e-01
# 22                        cleanliness  4.738283e-01
# 15                       seat_comfort  2.896253e-01
# 9               inflight_wifi_service -2.763154e-01
# 24           arrival_delay_in_minutes -2.351629e-01
# 16             inflight_entertainment -1.943981e-01
# 12                      gate_location  1.800609e-01
# 7                                 age -1.253162e-01
# 10  departure/arrival_time_convenient -1.189554e-01
# 8                     flight_distance -4.485705e-02
# 23         departure_delay_in_minutes  2.869425e-02
# 13                     food_and_drink -2.850388e-02
# 11             ease_of_online_booking -2.090234e-02
# 1                         gender_Male -5.329587e-03
# 0                       gender_Female  5.329587e-03
# 6                      class_Business -1.872184e-10
